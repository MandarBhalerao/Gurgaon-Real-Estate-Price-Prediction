# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %% [markdown]
# ### In insights module, we want to explain the user that which features affect the price and by what factor do they affect it
#
# #### ie we have to train a model again for doing inference. Some models are not good at inference like Deep learning models. While some are good for inference like Linear Regression
#
# #### Therefore, for our insights module, we will use Linear Regression for inference

# %%
df = pd.read_csv('mandar_gurgaon_properties_post_feature_selection_v2.csv').drop(columns=['store room','floor_category','balcony'])

# we dropped these 3 columns 'store room','floor_category','balcony' because the r2 score was not changing significantly due to these columns

# %%
# new_df = pd.read_csv('mandar_gurgaon_properties_post_feature_selection_v2.csv')
# new_df

# %%
# new_df['sector'] = new_df['sector'].str.replace('sector 17a','sector 17')
# new_df['sector'] = new_df['sector'].str.replace('sector 17b','sector 17')
# new_df['sector'] = new_df['sector'].str.replace('sector 37c','sector 37')
# new_df['sector'] = new_df['sector'].str.replace('sector 88b','sector 88')
# new_df['sector'] = new_df['sector'].str.replace('sector 99a','sector 99')
# new_df['sector'] = new_df['sector'].str.replace('sector 10a','sector 10')

# new_df.to_csv('mandar_gurgaon_properties_post_feature_selection_v2.csv',index=False)

# %%
df.head()
# Out:
#   property_type     sector  bedRoom  bathroom   agePossession  built_up_area  \
# 0          flat  sector 78        2         2  Moderately Old         1239.0
# 1          flat  sector 60        2         3  Relatively New         1250.0
# 2          flat  sector 90        3         3  Relatively New         1578.0
# 3         house   sector 2        6         6  Moderately Old         3611.0
# 4          flat  sector 63        4         4    New Property         3956.0
#
#    servant room  furnishing_type  price luxury_category
# 0             0                0   0.75             Low
# 1             1                1   2.15             Low
# 2             0                0   1.23             Low
# 3             0                0   5.00             Low
# 4             0                0   7.52          Medium

# %%
# df['sector'].unique().tolist()

# %%
# df['sector'].value_counts()

# %% [markdown]
# #### We will train a Linear Regression model on this data. ie our goal is to get the best r2 score, because we want to understand that how much variance our features are explaining about the target column

# %%
# df = pd.read_csv('mandar_gurgaon_properties_post_feature_selection_v2.csv')

# df['sector'] = df['sector'].str.replace('sector 36a','sector 36')
# df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
# df['sector'] = df['sector'].str.replace('sector 3 phase 2','sector 3')
# df['sector'] = df['sector'].str.replace('sector 3 phase 3 extension','sector 3')

# %%
# df.to_csv('mandar_gurgaon_properties_post_feature_selection_v2.csv',index=False)

# %%
# 0 -> unfurnished
# 1 -> semifurnished
# 2 -> furnished

# %%
# Numerical = bedRoom, bathroom, built_up_area, servant room   --> here we dont have to apply transformations
# Ordinal = property_type, furnishing_type, luxury_category    --> ordinal encoding is used where is natural order like low<medium<high
# OHE = sector, agePossession                                  --> here there is no natural order, so apply OHE

# %%
# to simplify, we are converting these 5 agePossession categories into 3 categories

df['agePossession'] = df['agePossession'].replace(
    {
        'Relatively New':'new',
        'Moderately Old':'old',
        'New Property' : 'new',
        'Old Property' : 'old',
        'Under Construction' : 'under construction'
    }
)

# %%
df.head()
# Out:
#   property_type     sector  bedRoom  bathroom agePossession  built_up_area  \
# 0          flat  sector 78        2         2           old         1239.0
# 1          flat  sector 60        2         3           new         1250.0
# 2          flat  sector 90        3         3           new         1578.0
# 3         house   sector 2        6         6           old         3611.0
# 4          flat  sector 63        4         4           new         3956.0
#
#    servant room  furnishing_type  price luxury_category
# 0             0                0   0.75             Low
# 1             1                1   2.15             Low
# 2             0                0   1.23             Low
# 3             0                0   5.00             Low
# 4             0                0   7.52          Medium

# %%
# doing ordinal encoding for property_type

df['property_type'] = df['property_type'].replace({'flat':0,'house':1})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_30292\2800025550.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['property_type'] = df['property_type'].replace({'flat':0,'house':1})

# %%
df.head()
# Out:
#    property_type     sector  bedRoom  bathroom agePossession  built_up_area  \
# 0              0  sector 78        2         2           old         1239.0
# 1              0  sector 60        2         3           new         1250.0
# 2              0  sector 90        3         3           new         1578.0
# 3              1   sector 2        6         6           old         3611.0
# 4              0  sector 63        4         4           new         3956.0
#
#    servant room  furnishing_type  price luxury_category
# 0             0                0   0.75             Low
# 1             1                1   2.15             Low
# 2             0                0   1.23             Low
# 3             0                0   5.00             Low
# 4             0                0   7.52          Medium

# %%
df['luxury_category'] = df['luxury_category'].replace({'Low':0,'Medium':1,'High':2})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_30292\2576796079.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['luxury_category'] = df['luxury_category'].replace({'Low':0,'Medium':1,'High':2})

# %%
df.head()
# Out:
#    property_type     sector  bedRoom  bathroom agePossession  built_up_area  \
# 0              0  sector 78        2         2           old         1239.0
# 1              0  sector 60        2         3           new         1250.0
# 2              0  sector 90        3         3           new         1578.0
# 3              1   sector 2        6         6           old         3611.0
# 4              0  sector 63        4         4           new         3956.0
#
#    servant room  furnishing_type  price  luxury_category
# 0             0                0   0.75                0
# 1             1                1   2.15                0
# 2             0                0   1.23                0
# 3             0                0   5.00                0
# 4             0                0   7.52                1

# %%
# this is doing OHE on sector and agePossession columns

new_df = pd.get_dummies(df,columns=['sector','agePossession'],drop_first=True)

# %%
new_df
# Out:
#       property_type  bedRoom  bathroom  built_up_area  servant room  \
# 0                 0        2         2         1239.0             0
# 1                 0        2         3         1250.0             1
# 2                 0        3         3         1578.0             0
# 3                 1        6         6         3611.0             0
# 4                 0        4         4         3956.0             0
# ...             ...      ...       ...            ...           ...
# 3549              0        5         4         2956.0             0
# 3550              0        3         3         1267.0             0
# 3551              0        3         4         2470.0             1
# 3552              0        3         3         1747.0             1
# 3553              1        2         3         1053.0             0
#
#       furnishing_type  price  luxury_category  sector_gwal pahari  \
# 0                   0   0.75                0               False
# 1                   1   2.15                0               False
# 2                   0   1.23                0               False
# 3                   0   5.00                0               False
# 4                   0   7.52                1               False
# ...               ...    ...              ...                 ...
# 3549                2   3.72                0               False
# 3550                0   1.30                0               False
# 3551                1   2.65                2               False
# 3552                0   1.30                1               False
# 3553                1   1.55                0               False
#
#       sector_manesar  ...  sector_sector 90  sector_sector 91  \
# 0              False  ...             False             False
# 1              False  ...             False             False
# 2              False  ...              True             False
# 3              False  ...             False             False
# 4              False  ...             False             False
# ...              ...  ...               ...               ...
# 3549           False  ...             False             False
# 3550           False  ...             False             False
# 3551           False  ...             False             False
# 3552           False  ...             False             False
# 3553           False  ...             False             False
#
#       sector_sector 92  sector_sector 93  sector_sector 95  sector_sector 99  \
# 0                False             False             False             False
# 1                False             False             False             False
# 2                False             False             False             False
# 3                False             False             False             False
# 4                False             False             False             False
# ...                ...               ...               ...               ...
# 3549             False             False             False             False
# 3550             False             False             False             False
# 3551             False             False             False             False
# 3552             False             False             False             False
# 3553             False             False             False             False
#
#       sector_sector 9a  sector_sohna road  agePossession_old  \
# 0                False              False               True
# 1                False              False              False
# 2                False              False              False
# 3                False              False               True
# 4                False              False              False
# ...                ...                ...                ...
# 3549             False              False              False
# 3550             False              False              False
# 3551             False              False               True
# 3552             False              False               True
# 3553             False               True              False
#
#       agePossession_under construction
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 3549                             False
# 3550                              True
# 3551                             False
# 3552                             False
# 3553                             False
#
# [3554 rows x 114 columns]

# %%
X = new_df.drop(columns=['price'])
y = new_df['price']

# %%
y_log = np.log1p(y)
# performing log transform on output column as it was becoming nearly normal distribution

# %%
y_log
# Out:
# 0       0.559616
# 1       1.147402
# 2       0.802002
# 3       1.791759
# 4       2.142416
#           ...
# 3549    1.551809
# 3550    0.832909
# 3551    1.294727
# 3552    0.832909
# 3553    0.936093
# Name: price, Length: 3554, dtype: float64

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled,columns=X.columns)

# %%
X_scaled
# Out:
#       property_type   bedRoom  bathroom  built_up_area  servant room  \
# 0         -0.517180 -0.877269 -0.874300      -0.511829     -0.747968
# 1         -0.517180 -0.877269 -0.184564      -0.502784      1.336956
# 2         -0.517180 -0.074329 -0.184564      -0.233105     -0.747968
# 3          1.933563  2.334488  1.884645       1.438415     -0.747968
# 4         -0.517180  0.728610  0.505173       1.722072     -0.747968
# ...             ...       ...       ...            ...           ...
# 3549      -0.517180  1.531549  0.505173       0.899878     -0.747968
# 3550      -0.517180 -0.074329 -0.184564      -0.488807     -0.747968
# 3551      -0.517180 -0.074329  0.505173       0.500292      1.336956
# 3552      -0.517180 -0.074329 -0.184564      -0.094154      1.336956
# 3553       1.933563 -0.877269 -0.184564      -0.664757     -0.747968
#
#       furnishing_type  luxury_category  sector_gwal pahari  sector_manesar  \
# 0           -0.658035        -0.984642           -0.071348       -0.093805
# 1            1.055266        -0.984642           -0.071348       -0.093805
# 2           -0.658035        -0.984642           -0.071348       -0.093805
# 3           -0.658035        -0.984642           -0.071348       -0.093805
# 4           -0.658035         0.440783           -0.071348       -0.093805
# ...               ...              ...                 ...             ...
# 3549         2.768566        -0.984642           -0.071348       -0.093805
# 3550        -0.658035        -0.984642           -0.071348       -0.093805
# 3551         1.055266         1.866207           -0.071348       -0.093805
# 3552        -0.658035         0.440783           -0.071348       -0.093805
# 3553         1.055266        -0.984642           -0.071348       -0.093805
#
#       sector_sector 1  ...  sector_sector 90  sector_sector 91  \
# 0           -0.041123  ...         -0.160267         -0.069328
# 1           -0.041123  ...         -0.160267         -0.069328
# 2           -0.041123  ...          6.239598         -0.069328
# 3           -0.041123  ...         -0.160267         -0.069328
# 4           -0.041123  ...         -0.160267         -0.069328
# ...               ...  ...               ...               ...
# 3549        -0.041123  ...         -0.160267         -0.069328
# 3550        -0.041123  ...         -0.160267         -0.069328
# 3551        -0.041123  ...         -0.160267         -0.069328
# 3552        -0.041123  ...         -0.160267         -0.069328
# 3553        -0.041123  ...         -0.160267         -0.069328
#
#       sector_sector 92  sector_sector 93  sector_sector 95  sector_sector 99  \
# 0            -0.170153         -0.050386         -0.125375         -0.109357
# 1            -0.170153         -0.050386         -0.125375         -0.109357
# 2            -0.170153         -0.050386         -0.125375         -0.109357
# 3            -0.170153         -0.050386         -0.125375         -0.109357
# 4            -0.170153         -0.050386         -0.125375         -0.109357
# ...                ...               ...               ...               ...
# 3549         -0.170153         -0.050386         -0.125375         -0.109357
# 3550         -0.170153         -0.050386         -0.125375         -0.109357
# 3551         -0.170153         -0.050386         -0.125375         -0.109357
# 3552         -0.170153         -0.050386         -0.125375         -0.109357
# 3553         -0.170153         -0.050386         -0.125375         -0.109357
#
#       sector_sector 9a  sector_sohna road  agePossession_old  \
# 0            -0.053119          -0.219245           1.654424
# 1            -0.053119          -0.219245          -0.604440
# 2            -0.053119          -0.219245          -0.604440
# 3            -0.053119          -0.219245           1.654424
# 4            -0.053119          -0.219245          -0.604440
# ...                ...                ...                ...
# 3549         -0.053119          -0.219245          -0.604440
# 3550         -0.053119          -0.219245          -0.604440
# 3551         -0.053119          -0.219245           1.654424
# 3552         -0.053119          -0.219245           1.654424
# 3553         -0.053119           4.561105          -0.604440
#
#       agePossession_under construction
# 0                            -0.290738
# 1                            -0.290738
# 2                            -0.290738
# 3                            -0.290738
# 4                            -0.290738
# ...                                ...
# 3549                         -0.290738
# 3550                          3.439524
# 3551                         -0.290738
# 3552                         -0.290738
# 3553                         -0.290738
#
# [3554 rows x 113 columns]

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(LinearRegression(), X_scaled, y_log, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.8522471718971687, 0.022363208444418456)

# %%
lr = LinearRegression()
ridge = Ridge(alpha=0.0001)

# %%
lr.fit(X_scaled,y_log)
# Out:
# LinearRegression()

# %%
ridge.fit(X_scaled,y_log)
# Out:
# Ridge(alpha=0.0001)

# %%
lr.coef_.shape
# Out:
# (113,)

# %%
coef_df = pd.DataFrame(ridge.coef_.reshape(1,113),columns=X.columns).stack().reset_index().drop(columns=['level_0']).rename(columns={'level_1':'feature',0:'coef'})

# %%
coef_df
# Out:
#                               feature      coef
# 0                       property_type  0.120977
# 1                             bedRoom  0.053679
# 2                            bathroom  0.065013
# 3                       built_up_area  0.210413
# 4                        servant room  0.050877
# ..                                ...       ...
# 108                  sector_sector 99 -0.010226
# 109                  sector_sector 9a -0.005074
# 110                 sector_sohna road -0.029466
# 111                 agePossession_old -0.007465
# 112  agePossession_under construction  0.015758
#
# [113 rows x 2 columns]

# %% [markdown]
# ### We have got the weights of the coeficients after training. Below is the regression analysis

# %%
# 1. Import necessary libraries
import statsmodels.api as sm

# 2. Add a constant to X
X_with_const = sm.add_constant(X_scaled)

# 3. Fit the model
model = sm.OLS(y_log, X_with_const).fit()

# 4. Obtain summary statistics
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     195.1
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):               0.00
# Time:                        15:59:38   Log-Likelihood:                 590.14
# No. Observations:                3554   AIC:                            -952.3
# Df Residuals:                    3440   BIC:                            -248.2
# Df Model:                         113
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                1.0464      0.003    299.455      0.000       1.040       1.053
# property_type                        0.1210      0.005     22.823      0.000       0.111       0.131
# bedRoom                              0.0537      0.007      8.149      0.000       0.041       0.067
# bathroom                             0.0650      0.007      9.537      0.000       0.052       0.078
# built_up_area                        0.2104      0.005     41.705      0.000       0.201       0.220
# servant room                         0.0509      0.005     11.222      0.000       0.042       0.060
# furnishing_type                      0.0089      0.004      2.198      0.028       0.001       0.017
# luxury_category                      0.0062      0.004      1.532      0.126      -0.002       0.014
# sector_gwal pahari                   0.0099      0.006      1.568      0.117      -0.002       0.022
# sector_manesar                      -0.0227      0.008     -2.919      0.004      -0.038      -0.007
# sector_sector 1                     -0.0052      0.005     -1.119      0.263      -0.014       0.004
# sector_sector 10                     0.0052      0.005      1.084      0.278      -0.004       0.015
# sector_sector 102                    0.0272      0.013      2.063      0.039       0.001       0.053
# sector_sector 103                   -0.0028      0.009     -0.316      0.752      -0.020       0.014
# sector_sector 104                    0.0021      0.011      0.195      0.845      -0.019       0.023
# sector_sector 105                   -0.0195      0.007     -2.944      0.003      -0.033      -0.007
# sector_sector 106                    0.0007      0.008      0.079      0.937      -0.016       0.017
# sector_sector 107                   -0.0129      0.010     -1.277      0.202      -0.033       0.007
# sector_sector 108                    0.0169      0.010      1.687      0.092      -0.003       0.037
# sector_sector 109                    0.0262      0.012      2.191      0.029       0.003       0.050
# sector_sector 11                    -0.0150      0.006     -2.452      0.014      -0.027      -0.003
# sector_sector 110                    0.0088      0.007      1.273      0.203      -0.005       0.022
# sector_sector 111                    0.0163      0.007      2.408      0.016       0.003       0.030
# sector_sector 112                    0.0309      0.007      4.455      0.000       0.017       0.044
# sector_sector 113                    0.0323      0.009      3.663      0.000       0.015       0.050
# sector_sector 12                    -0.0196      0.008     -2.482      0.013      -0.035      -0.004
# sector_sector 13                    -0.0123      0.005     -2.385      0.017      -0.022      -0.002
# sector_sector 14                     0.0287      0.006      4.493      0.000       0.016       0.041
# sector_sector 15                     0.0033      0.005      0.699      0.484      -0.006       0.012
# sector_sector 17                     0.0138      0.005      2.611      0.009       0.003       0.024
# sector_sector 2                      0.0066      0.010      0.640      0.522      -0.014       0.027
# sector_sector 21                    -0.0094      0.005     -2.029      0.043      -0.019      -0.000
# sector_sector 22                     0.0355      0.007      5.394      0.000       0.023       0.048
# sector_sector 23                     0.0021      0.006      0.368      0.713      -0.009       0.013
# sector_sector 24                     0.0176      0.007      2.667      0.008       0.005       0.031
# sector_sector 25                     0.0575      0.008      6.835      0.000       0.041       0.074
# sector_sector 26                     0.0738      0.009      8.482      0.000       0.057       0.091
# sector_sector 27                     0.0067      0.004      1.707      0.088      -0.001       0.014
# sector_sector 28                     0.0418      0.009      4.903      0.000       0.025       0.059
# sector_sector 3                     -0.0212      0.009     -2.483      0.013      -0.038      -0.004
# sector_sector 30                     0.0062      0.004      1.391      0.164      -0.003       0.015
# sector_sector 31                     0.0224      0.005      4.227      0.000       0.012       0.033
# sector_sector 33                     0.0259      0.011      2.442      0.015       0.005       0.047
# sector_sector 36                     0.0026      0.007      0.378      0.706      -0.011       0.016
# sector_sector 37                    -0.0114      0.010     -1.193      0.233      -0.030       0.007
# sector_sector 37d                    0.0012      0.010      0.115      0.908      -0.019       0.022
# sector_sector 38                     0.0121      0.005      2.280      0.023       0.002       0.022
# sector_sector 39                     0.0026      0.005      0.476      0.634      -0.008       0.013
# sector_sector 4                     -0.0210      0.009     -2.306      0.021      -0.039      -0.003
# sector_sector 40                     0.0076      0.004      1.691      0.091      -0.001       0.016
# sector_sector 41                     0.0168      0.005      3.078      0.002       0.006       0.027
# sector_sector 43                     0.0603      0.010      5.971      0.000       0.040       0.080
# sector_sector 45                     0.0269      0.005      5.386      0.000       0.017       0.037
# sector_sector 46                     0.0158      0.005      2.879      0.004       0.005       0.026
# sector_sector 47                     0.0128      0.006      2.096      0.036       0.001       0.025
# sector_sector 48                     0.0541      0.010      5.469      0.000       0.035       0.073
# sector_sector 49                     0.0317      0.009      3.509      0.000       0.014       0.049
# sector_sector 5                     -0.0033      0.005     -0.717      0.473      -0.012       0.006
# sector_sector 50                     0.0717      0.010      6.912      0.000       0.051       0.092
# sector_sector 51                     0.0002      0.005      0.046      0.964      -0.009       0.010
# sector_sector 52                     0.0048      0.006      0.829      0.407      -0.007       0.016
# sector_sector 53                     0.0478      0.006      8.225      0.000       0.036       0.059
# sector_sector 54                     0.0456      0.007      6.268      0.000       0.031       0.060
# sector_sector 55                     0.0125      0.005      2.364      0.018       0.002       0.023
# sector_sector 56                     0.0118      0.010      1.216      0.224      -0.007       0.031
# sector_sector 57                     0.0251      0.007      3.602      0.000       0.011       0.039
# sector_sector 58                     0.0236      0.005      4.910      0.000       0.014       0.033
# sector_sector 59                     0.0318      0.005      6.437      0.000       0.022       0.042
# sector_sector 6                     -0.0158      0.005     -2.907      0.004      -0.027      -0.005
# sector_sector 60                     0.0240      0.006      4.016      0.000       0.012       0.036
# sector_sector 61                     0.0367      0.009      4.264      0.000       0.020       0.054
# sector_sector 62                     0.0429      0.006      7.065      0.000       0.031       0.055
# sector_sector 63                     0.0349      0.006      5.995      0.000       0.023       0.046
# sector_sector 63a                    0.0235      0.006      3.973      0.000       0.012       0.035
# sector_sector 65                     0.0712      0.012      5.938      0.000       0.048       0.095
# sector_sector 66                     0.0529      0.009      6.087      0.000       0.036       0.070
# sector_sector 67                     0.0409      0.009      4.445      0.000       0.023       0.059
# sector_sector 67a                    0.0087      0.007      1.304      0.192      -0.004       0.022
# sector_sector 68                     0.0110      0.008      1.437      0.151      -0.004       0.026
# sector_sector 69                     0.0186      0.012      1.500      0.134      -0.006       0.043
# sector_sector 7                     -0.0074      0.008     -0.908      0.364      -0.024       0.009
# sector_sector 70                     0.0056      0.009      0.602      0.547      -0.013       0.024
# sector_sector 70a                    0.0172      0.010      1.764      0.078      -0.002       0.036
# sector_sector 71                    -0.0033      0.007     -0.446      0.656      -0.018       0.011
# sector_sector 72                     0.0303      0.008      4.002      0.000       0.015       0.045
# sector_sector 73                    -0.0014      0.004     -0.350      0.726      -0.009       0.007
# sector_sector 74                     0.0222      0.006      3.504      0.000       0.010       0.035
# sector_sector 76                     0.0002      0.006      0.040      0.968      -0.011       0.012
# sector_sector 77                     0.0008      0.007      0.112      0.911      -0.014       0.015
# sector_sector 78                    -0.0043      0.006     -0.707      0.480      -0.016       0.008
# sector_sector 79                     0.0133      0.011      1.179      0.238      -0.009       0.035
# sector_sector 8                     -0.0135      0.005     -2.801      0.005      -0.023      -0.004
# sector_sector 80                     0.0002      0.004      0.047      0.962      -0.009       0.009
# sector_sector 81                     0.0157      0.012      1.305      0.192      -0.008       0.039
# sector_sector 82                     0.0007      0.009      0.077      0.938      -0.016       0.018
# sector_sector 82a                    0.0098      0.006      1.511      0.131      -0.003       0.022
# sector_sector 83                    -0.0010      0.011     -0.095      0.924      -0.022       0.020
# sector_sector 84                    -0.0102      0.009     -1.093      0.274      -0.029       0.008
# sector_sector 85                     0.0089      0.013      0.674      0.500      -0.017       0.035
# sector_sector 86                    -0.0036      0.010     -0.351      0.726      -0.024       0.017
# sector_sector 88                 -4.922e-05      0.004     -0.012      0.990      -0.008       0.008
# sector_sector 88a                    0.0087      0.007      1.273      0.203      -0.005       0.022
# sector_sector 89                     0.0021      0.010      0.207      0.836      -0.017       0.021
# sector_sector 9                     -0.0135      0.006     -2.409      0.016      -0.024      -0.003
# sector_sector 90                    -0.0129      0.012     -1.060      0.289      -0.037       0.011
# sector_sector 91                    -0.0001      0.006     -0.017      0.987      -0.012       0.012
# sector_sector 92                    -0.0285      0.013     -2.233      0.026      -0.053      -0.003
# sector_sector 93                    -0.0039      0.005     -0.772      0.440      -0.014       0.006
# sector_sector 95                    -0.0251      0.010     -2.561      0.010      -0.044      -0.006
# sector_sector 99                    -0.0102      0.009     -1.171      0.242      -0.027       0.007
# sector_sector 9a                    -0.0051      0.005     -0.960      0.337      -0.015       0.005
# sector_sohna road                   -0.0295      0.016     -1.852      0.064      -0.061       0.002
# agePossession_old                   -0.0075      0.005     -1.501      0.133      -0.017       0.002
# agePossession_under construction     0.0158      0.004      3.893      0.000       0.008       0.024
# ==============================================================================
# Omnibus:                      511.474   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4718.193
# Skew:                          -0.378   Prob(JB):                         0.00
# Kurtosis:                       8.594   Cond. No.                         40.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_log.std()
# Out:
# 0.5579613263072811

# %%
X_scaled['bedRoom'].std()
# Out:
# 1.000140716246387

# %%
0.21 * (0.557/1)
# Out:
# 0.11697

# %%
np.expm1(0.030)
# Out:
# 0.030454533953516858

# %%
2.4726962617564903e-05 * 100
# Out:
# 0.0024726962617564905
